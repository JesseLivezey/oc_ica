# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

import oc_ica
from oc_ica.analysis import normalize_W
from oc_ica.optimizers.ica_optimizers import sgd
import mpl_toolkits.mplot3d.axes3d as p3

# %% [markdown]
# # 2D Animation

# %%
n_arrows = 6
dim = 2
n_times = 1000
rng = np.random.RandomState(10)

# %%
X, Y = np.zeros(n_arrows), np.zeros(n_arrows)
w = np.zeros((n_times, n_arrows, dim))
w[0] = np.random.randn(n_arrows, dim)
w[0] = np.tile(np.eye(dim), (n_arrows // dim, 1)) + rng.randn(n_arrows, dim) / 100
model = oc_ica.models.ica.ICA(dim, n_arrows, optimizer='sgd', learning_rule=sgd, lambd=0.,
                             degeneracy='L4', rng=rng, w_init=w[0])

U, V = w[0].T

d = np.zeros((dim, 10))
for ii in range(n_times-1):
    w[ii+1] = model.fit(d, batch_size=10, n_epochs=1).components_
w = normalize_W(w.reshape(n_times * n_arrows, dim)).reshape(n_times, n_arrows, dim)

fig, ax = plt.subplots(1, figsize=(4, 4))
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
Q = ax.quiver(X, Y, U, V, units='xy', scale=1)
Qn = ax.quiver(X, Y, -U, -V, units='xy', scale=1, color='b')

def update_quiver(num, Q, Qn, w):
    """updates the horizontal and vertical vector components by a
    fixed increment on each frame
    """
    U, V = w[(num+1) % n_times].T

    Q.set_UVC(U,V)
    Qn.set_UVC(-U,-V)

    return Q,

# you need to set blit=False, or the first set of arrows never gets
# cleared on subsequent frames
anim = animation.FuncAnimation(fig, update_quiver, fargs=(Q, Qn, w),
                               interval=10, blit=False)

plt.show()
# Out:
# Overcomplete ICA
# Degeneracy control: L4
# ICA with SGD done!0
# Final loss value: 2.998972177505493
# ICA with SGD done!0
# Final loss value: 2.9988460540771484
# ICA with SGD done!0
# Final loss value: 2.9987025260925293
# ICA with SGD done!0
# Final loss value: 2.9985430240631104
# ICA with SGD done!0
# Final loss value: 2.9983632564544678
# ICA with SGD done!0
# Final loss value: 2.9981603622436523
# ICA with SGD done!0
# Final loss value: 2.997934341430664
# ICA with SGD done!0
# Final loss value: 2.9976794719696045
# ICA with SGD done!0
# Final loss value: 2.9973931312561035
# ICA with SGD done!0
# Final loss value: 2.9970719814300537
# ICA with SGD done!0
# Final loss value: 2.996711254119873
# ICA with SGD done!0
# Final loss value: 2.9963061809539795
# ICA with SGD done!0
# Final loss value: 2.9958508014678955
# ICA with SGD done!0
# Final loss value: 2.9953408241271973
# ICA with SGD done!0
# Final loss value: 2.9947683811187744
# ICA with SGD done!0
# Final loss value: 2.9941256046295166
# ICA with SGD done!0
# Final loss value: 2.9934041500091553
# ICA with SGD done!0
# Final loss value: 2.9925954341888428
# ICA with SGD done!0
# Final loss value: 2.991687774658203
# ICA with SGD done!0
# Final loss value: 2.9906697273254395
# ICA with SGD done!0
# Final loss value: 2.9895291328430176
# ICA with SGD done!0
# Final loss value: 2.988250732421875
# ICA with SGD done!0
# Final loss value: 2.986818790435791
# ICA with SGD done!0
# Final loss value: 2.9852142333984375
# ICA with SGD done!0
# Final loss value: 2.9834177494049072
# ICA with SGD done!0
# Final loss value: 2.981407642364502
# ICA with SGD done!0
# Final loss value: 2.979158878326416
# ICA with SGD done!0
# Final loss value: 2.9766440391540527
# ICA with SGD done!0
# Final loss value: 2.9738354682922363
# ICA with SGD done!0
# Final loss value: 2.970698833465576
# ICA with SGD done!0
# Final loss value: 2.967198371887207
# ICA with SGD done!0
# Final loss value: 2.9632978439331055
# ICA with SGD done!0
# Final loss value: 2.9589526653289795
# ICA with SGD done!0
# Final loss value: 2.954117774963379
# ICA with SGD done!0
# Final loss value: 2.948744058609009
# ICA with SGD done!0
# Final loss value: 2.9427807331085205
# ICA with SGD done!0
# Final loss value: 2.9361698627471924
# ICA with SGD done!0
# Final loss value: 2.9288551807403564
# ICA with SGD done!0
# Final loss value: 2.920774459838867
# ICA with SGD done!0
# Final loss value: 2.9118642807006836
# ICA with SGD done!0
# Final loss value: 2.902059555053711
# ICA with SGD done!0
# Final loss value: 2.891298294067383
# ICA with SGD done!0
# Final loss value: 2.8795135021209717
# ICA with SGD done!0
# Final loss value: 2.8666458129882812
# ICA with SGD done!0
# Final loss value: 2.85263729095459
# ICA with SGD done!0
# Final loss value: 2.837437629699707
# ICA with SGD done!0
# Final loss value: 2.82100248336792
# ICA with SGD done!0
# Final loss value: 2.8033013343811035
# ICA with SGD done!0
# Final loss value: 2.784313678741455
# ICA with SGD done!0
# Final loss value: 2.7640368938446045
# ICA with SGD done!0
# Final loss value: 2.742483615875244
# ICA with SGD done!0
# Final loss value: 2.7196872234344482
# ICA with SGD done!0
# Final loss value: 2.695702075958252
# ICA with SGD done!0
# Final loss value: 2.670604705810547
# ICA with SGD done!0
# Final loss value: 2.644493818283081
# ICA with SGD done!0
# Final loss value: 2.6174874305725098
# ICA with SGD done!0
# Final loss value: 2.5897247791290283
# ICA with SGD done!0
# Final loss value: 2.561361312866211
# ICA with SGD done!0
# Final loss value: 2.5325653553009033
# ICA with SGD done!0
# Final loss value: 2.5035176277160645
# ICA with SGD done!0
# Final loss value: 2.474400043487549
# ICA with SGD done!0
# Final loss value: 2.4453959465026855
# ICA with SGD done!0
# Final loss value: 2.416684865951538
# ICA with SGD done!0
# Final loss value: 2.3884363174438477
# ICA with SGD done!0
# Final loss value: 2.360806941986084
# ICA with SGD done!0
# Final loss value: 2.333937406539917
# ICA with SGD done!0
# Final loss value: 2.3079493045806885
# ICA with SGD done!0
# Final loss value: 2.282944679260254
# ICA with SGD done!0
# Final loss value: 2.259005069732666
# ICA with SGD done!0
# Final loss value: 2.236189126968384
# ICA with SGD done!0
# Final loss value: 2.214538335800171
# ICA with SGD done!0
# Final loss value: 2.19407320022583
# ICA with SGD done!0
# Final loss value: 2.1747989654541016
# ICA with SGD done!0
# Final loss value: 2.1567063331604004
# ICA with SGD done!0
# Final loss value: 2.1397712230682373
# ICA with SGD done!0
# Final loss value: 2.1239612102508545
# ICA with SGD done!0
# Final loss value: 2.1092348098754883
# ICA with SGD done!0
# Final loss value: 2.095543146133423
# ICA with SGD done!0
# Final loss value: 2.0828347206115723
# ICA with SGD done!0
# Final loss value: 2.0710537433624268
# ICA with SGD done!0
# Final loss value: 2.060142993927002
# ICA with SGD done!0
# Final loss value: 2.0500454902648926
# ICA with SGD done!0
# Final loss value: 2.0407047271728516
# ICA with SGD done!0
# Final loss value: 2.0320639610290527
# ICA with SGD done!0
# Final loss value: 2.024070978164673
# ICA with SGD done!0
# Final loss value: 2.016674518585205
# ICA with SGD done!0
# Final loss value: 2.0098254680633545
# ICA with SGD done!0
# Final loss value: 2.00347900390625
# ICA with SGD done!0
# Final loss value: 1.9975920915603638
# ICA with SGD done!0
# Final loss value: 1.9921247959136963
# ICA with SGD done!0
# Final loss value: 1.9870414733886719
# ICA with SGD done!0
# Final loss value: 1.982306957244873
# ICA with SGD done!0
# Final loss value: 1.9778919219970703
# ICA with SGD done!0
# Final loss value: 1.9737672805786133
# ICA with SGD done!0
# Final loss value: 1.9699065685272217
# ICA with SGD done!0
# Final loss value: 1.9662866592407227
# ICA with SGD done!0
# Final loss value: 1.962886095046997
# ICA with SGD done!0
# Final loss value: 1.959686279296875
# ICA with SGD done!0
# Final loss value: 1.9566688537597656
# ICA with SGD done!0
# Final loss value: 1.9538179636001587
# ICA with SGD done!0
# Final loss value: 1.951120376586914
# ICA with SGD done!0
# Final loss value: 1.9485621452331543
# ICA with SGD done!0
# Final loss value: 1.9461325407028198
# ICA with SGD done!0
# Final loss value: 1.9438207149505615
# ICA with SGD done!0
# Final loss value: 1.9416173696517944
# ICA with SGD done!0
# Final loss value: 1.9395148754119873
# ICA with SGD done!0
# Final loss value: 1.937504529953003
# ICA with SGD done!0
# Final loss value: 1.9355802536010742
# ICA with SGD done!0
# Final loss value: 1.9337364435195923
# ICA with SGD done!0
# Final loss value: 1.9319666624069214
# ICA with SGD done!0
# Final loss value: 1.9302669763565063
# ICA with SGD done!0
# Final loss value: 1.9286320209503174
# ICA with SGD done!0
# Final loss value: 1.9270586967468262
# ICA with SGD done!0
# Final loss value: 1.9255427122116089
# ICA with SGD done!0
# Final loss value: 1.9240812063217163
# ICA with SGD done!0
# Final loss value: 1.922670841217041
# ICA with SGD done!0
# Final loss value: 1.9213098287582397
# ICA with SGD done!0
# Final loss value: 1.9199949502944946
# ICA with SGD done!0
# Final loss value: 1.9187240600585938
# ICA with SGD done!0
# Final loss value: 1.9174953699111938
# ICA with SGD done!0
# Final loss value: 1.9163070917129517
# ICA with SGD done!0
# Final loss value: 1.9151573181152344
# ICA with SGD done!0
# Final loss value: 1.9140442609786987
# ICA with SGD done!0
# Final loss value: 1.9129670858383179
# ICA with SGD done!0
# Final loss value: 1.911923885345459
# ICA with SGD done!0
# Final loss value: 1.910913109779358
# ICA with SGD done!0
# Final loss value: 1.9099338054656982
# ICA with SGD done!0
# Final loss value: 1.9089857339859009
# ICA with SGD done!0
# Final loss value: 1.9080665111541748
# ICA with SGD done!0
# Final loss value: 1.9071755409240723
# ICA with SGD done!0
# Final loss value: 1.9063122272491455
# ICA with SGD done!0
# Final loss value: 1.90547513961792
# ICA with SGD done!0
# Final loss value: 1.904664158821106
# ICA with SGD done!0
# Final loss value: 1.9038774967193604
# ICA with SGD done!0
# Final loss value: 1.903114676475525
# ICA with SGD done!0
# Final loss value: 1.9023747444152832
# ICA with SGD done!0
# Final loss value: 1.9016579389572144
# ICA with SGD done!0
# Final loss value: 1.9009621143341064
# ICA with SGD done!0
# Final loss value: 1.9002877473831177
# ICA with SGD done!0
# Final loss value: 1.8996330499649048
# ICA with SGD done!0
# Final loss value: 1.8989981412887573
# ICA with SGD done!0
# Final loss value: 1.898382306098938
# ICA with SGD done!0
# Final loss value: 1.8977850675582886
# ICA with SGD done!0
# Final loss value: 1.8972053527832031
# ICA with SGD done!0
# Final loss value: 1.8966422080993652
# ICA with SGD done!0
# Final loss value: 1.8960967063903809
# ICA with SGD done!0
# Final loss value: 1.8955665826797485
# ICA with SGD done!0
# Final loss value: 1.8950518369674683
# ICA with SGD done!0
# Final loss value: 1.8945527076721191
# ICA with SGD done!0
# Final loss value: 1.894067645072937
# ICA with SGD done!0
# Final loss value: 1.8935966491699219
# ICA with SGD done!0
# Final loss value: 1.893139362335205
# ICA with SGD done!0
# Final loss value: 1.8926948308944702
# ICA with SGD done!0
# Final loss value: 1.892263412475586
# ICA with SGD done!0
# Final loss value: 1.8918441534042358
# ICA with SGD done!0
# Final loss value: 1.8914365768432617
# ICA with SGD done!0
# Final loss value: 1.891040563583374
# ICA with SGD done!0
# Final loss value: 1.8906553983688354
# ICA with SGD done!0
# Final loss value: 1.890280842781067
# ICA with SGD done!0
# Final loss value: 1.889917254447937
# ICA with SGD done!0
# Final loss value: 1.8895632028579712
# ICA with SGD done!0
# Final loss value: 1.8892186880111694
# ICA with SGD done!0
# Final loss value: 1.8888838291168213
# ICA with SGD done!0
# Final loss value: 1.8885576725006104
# ICA with SGD done!0
# Final loss value: 1.8882402181625366
# ICA with SGD done!0
# Final loss value: 1.8879315853118896
# ICA with SGD done!0
# Final loss value: 1.8876312971115112
# ICA with SGD done!0
# Final loss value: 1.8873380422592163
# ICA with SGD done!0
# Final loss value: 1.8870527744293213
# ICA with SGD done!0
# Final loss value: 1.8867754936218262
# ICA with SGD done!0
# Final loss value: 1.886505126953125
# ICA with SGD done!0
# Final loss value: 1.8862411975860596
# ICA with SGD done!0
# Final loss value: 1.8859844207763672
# ICA with SGD done!0
# Final loss value: 1.8857340812683105
# ICA with SGD done!0
# Final loss value: 1.885489821434021
# ICA with SGD done!0
# Final loss value: 1.8852518796920776
# ICA with SGD done!0
# Final loss value: 1.8850197792053223
# ICA with SGD done!0
# Final loss value: 1.8847936391830444
# ICA with SGD done!0
# Final loss value: 1.884572982788086
# ICA with SGD done!0
# Final loss value: 1.8843574523925781
# ICA with SGD done!0
# Final loss value: 1.8841472864151
# ICA with SGD done!0
# Final loss value: 1.8839422464370728
# ICA with SGD done!0
# Final loss value: 1.8837422132492065
# ICA with SGD done!0
# Final loss value: 1.8835469484329224
# ICA with SGD done!0
# Final loss value: 1.8833562135696411
# ICA with SGD done!0
# Final loss value: 1.8831701278686523
# ICA with SGD done!0
# Final loss value: 1.8829879760742188
# ICA with SGD done!0
# Final loss value: 1.882810354232788
# ICA with SGD done!0
# Final loss value: 1.8826372623443604
# ICA with SGD done!0
# Final loss value: 1.8824677467346191
# ICA with SGD done!0
# Final loss value: 1.882301926612854
# ICA with SGD done!0
# Final loss value: 1.8821405172348022
# ICA with SGD done!0
# Final loss value: 1.8819823265075684
# ICA with SGD done!0
# Final loss value: 1.8818281888961792
# ICA with SGD done!0
# Final loss value: 1.8816769123077393
# ICA with SGD done!0
# Final loss value: 1.8815295696258545
# ICA with SGD done!0
# Final loss value: 1.881385326385498
# ICA with SGD done!0
# Final loss value: 1.8812445402145386
# ICA with SGD done!0
# Final loss value: 1.8811066150665283
# ICA with SGD done!0
# Final loss value: 1.880971908569336
# ICA with SGD done!0
# Final loss value: 1.8808403015136719
# ICA with SGD done!0
# Final loss value: 1.8807119131088257
# ICA with SGD done!0
# Final loss value: 1.8805859088897705
# ICA with SGD done!0
# Final loss value: 1.880462884902954
# ICA with SGD done!0
# Final loss value: 1.8803421258926392
# ICA with SGD done!0
# Final loss value: 1.8802242279052734
# ICA with SGD done!0
# Final loss value: 1.8801093101501465
# ICA with SGD done!0
# Final loss value: 1.8799961805343628
# ICA with SGD done!0
# Final loss value: 1.879886269569397
# ICA with SGD done!0
# Final loss value: 1.8797787427902222
# ICA with SGD done!0
# Final loss value: 1.8796732425689697
# ICA with SGD done!0
# Final loss value: 1.8795701265335083
# ICA with SGD done!0
# Final loss value: 1.8794690370559692
# ICA with SGD done!0
# Final loss value: 1.8793702125549316
# ICA with SGD done!0
# Final loss value: 1.8792736530303955
# ICA with SGD done!0
# Final loss value: 1.8791790008544922
# ICA with SGD done!0
# Final loss value: 1.8790866136550903
# ICA with SGD done!0
# Final loss value: 1.8789963722229004
# ICA with SGD done!0
# Final loss value: 1.878907322883606
# ICA with SGD done!0
# Final loss value: 1.8788210153579712
# ICA with SGD done!0
# Final loss value: 1.8787362575531006
# ICA with SGD done!0
# Final loss value: 1.8786532878875732
# ICA with SGD done!0
# Final loss value: 1.8785723447799683
# ICA with SGD done!0
# Final loss value: 1.8784923553466797
# ICA with SGD done!0
# Final loss value: 1.8784151077270508
# ICA with SGD done!0
# Final loss value: 1.8783390522003174
# ICA with SGD done!0
# Final loss value: 1.8782645463943481
# ICA with SGD done!0
# Final loss value: 1.8781919479370117
# ICA with SGD done!0
# Final loss value: 1.8781206607818604
# ICA with SGD done!0
# Final loss value: 1.8780509233474731
# ICA with SGD done!0
# Final loss value: 1.87798273563385
# ICA with SGD done!0
# Final loss value: 1.877915620803833
# ICA with SGD done!0
# Final loss value: 1.8778506517410278
# ICA with SGD done!0
# Final loss value: 1.8777871131896973
# ICA with SGD done!0
# Final loss value: 1.877724051475525
# ICA with SGD done!0
# Final loss value: 1.8776633739471436
# ICA with SGD done!0
# Final loss value: 1.8776034116744995
# ICA with SGD done!0
# Final loss value: 1.87754487991333
# ICA with SGD done!0
# Final loss value: 1.8774875402450562
# ICA with SGD done!0
# Final loss value: 1.8774313926696777
# ICA with SGD done!0
# Final loss value: 1.8773765563964844
# ICA with SGD done!0
# Final loss value: 1.8773229122161865
# ICA with SGD done!0
# Final loss value: 1.8772703409194946
# ICA with SGD done!0
# Final loss value: 1.8772190809249878
# ICA with SGD done!0
# Final loss value: 1.8771687746047974
# ICA with SGD done!0
# Final loss value: 1.8771196603775024
# ICA with SGD done!0
# Final loss value: 1.8770716190338135
# ICA with SGD done!0
# Final loss value: 1.877024531364441
# ICA with SGD done!0
# Final loss value: 1.8769786357879639
# ICA with SGD done!0
# Final loss value: 1.8769333362579346
# ICA with SGD done!0
# Final loss value: 1.8768895864486694
# ICA with SGD done!0
# Final loss value: 1.8768459558486938
# ICA with SGD done!0
# Final loss value: 1.876803994178772
# ICA with SGD done!0
# Final loss value: 1.8767629861831665
# ICA with SGD done!0
# Final loss value: 1.8767224550247192
# ICA with SGD done!0
# Final loss value: 1.876682996749878
# ICA with SGD done!0
# Final loss value: 1.8766447305679321
# ICA with SGD done!0
# Final loss value: 1.8766069412231445
# ICA with SGD done!0
# Final loss value: 1.8765698671340942
# ICA with SGD done!0
# Final loss value: 1.87653386592865
# ICA with SGD done!0
# Final loss value: 1.8764985799789429
# ICA with SGD done!0
# Final loss value: 1.876463770866394
# ICA with SGD done!0
# Final loss value: 1.8764300346374512
# ICA with SGD done!0
# Final loss value: 1.8763970136642456
# ICA with SGD done!0
# Final loss value: 1.8763644695281982
# ICA with SGD done!0
# Final loss value: 1.8763333559036255
# ICA with SGD done!0
# Final loss value: 1.8763024806976318
# ICA with SGD done!0
# Final loss value: 1.876272439956665
# ICA with SGD done!0
# Final loss value: 1.8762426376342773
# ICA with SGD done!0
# Final loss value: 1.8762140274047852
# ICA with SGD done!0
# Final loss value: 1.8761855363845825
# ICA with SGD done!0
# Final loss value: 1.8761577606201172
# ICA with SGD done!0
# Final loss value: 1.8761311769485474
# ICA with SGD done!0
# Final loss value: 1.876104712486267
# ICA with SGD done!0
# Final loss value: 1.8760789632797241
# ICA with SGD done!0
# Final loss value: 1.8760535717010498
# ICA with SGD done!0
# Final loss value: 1.8760288953781128
# ICA with SGD done!0
# Final loss value: 1.8760045766830444
# ICA with SGD done!0
# Final loss value: 1.8759814500808716
# ICA with SGD done!0
# Final loss value: 1.8759583234786987
# ICA with SGD done!0
# Final loss value: 1.8759359121322632
# ICA with SGD done!0
# Final loss value: 1.8759138584136963
# ICA with SGD done!0
# Final loss value: 1.8758924007415771
# ICA with SGD done!0
# Final loss value: 1.8758710622787476
# ICA with SGD done!0
# Final loss value: 1.875850796699524
# ICA with SGD done!0
# Final loss value: 1.8758307695388794
# ICA with SGD done!0
# Final loss value: 1.8758108615875244
# ICA with SGD done!0
# Final loss value: 1.875792145729065
# ICA with SGD done!0
# Final loss value: 1.8757731914520264
# ICA with SGD done!0
# Final loss value: 1.8757548332214355
# ICA with SGD done!0
# Final loss value: 1.8757373094558716
# ICA with SGD done!0
# Final loss value: 1.8757197856903076
# ICA with SGD done!0
# Final loss value: 1.8757026195526123
# ICA with SGD done!0
# Final loss value: 1.875685691833496
# ICA with SGD done!0
# Final loss value: 1.8756697177886963
# ICA with SGD done!0
# Final loss value: 1.875653624534607
# ICA with SGD done!0
# Final loss value: 1.8756383657455444
# ICA with SGD done!0
# Final loss value: 1.875623106956482
# ICA with SGD done!0
# Final loss value: 1.875608205795288
# ICA with SGD done!0
# Final loss value: 1.8755933046340942
# ICA with SGD done!0
# Final loss value: 1.8755793571472168
# ICA with SGD done!0
# Final loss value: 1.8755654096603394
# ICA with SGD done!0
# Final loss value: 1.8755518198013306
# ICA with SGD done!0
# Final loss value: 1.875538945198059
# ICA with SGD done!0
# Final loss value: 1.875525951385498
# ICA with SGD done!0
# Final loss value: 1.8755135536193848
# ICA with SGD done!0
# Final loss value: 1.8755011558532715
# ICA with SGD done!0
# Final loss value: 1.8754888772964478
# ICA with SGD done!0
# Final loss value: 1.8754773139953613
# ICA with SGD done!0
# Final loss value: 1.875466227531433
# ICA with SGD done!0
# Final loss value: 1.8754545450210571
# ICA with SGD done!0
# Final loss value: 1.8754435777664185
# ICA with SGD done!0
# Final loss value: 1.875433087348938
# ICA with SGD done!0
# Final loss value: 1.8754223585128784
# ICA with SGD done!0
# Final loss value: 1.8754122257232666
# ICA with SGD done!0
# Final loss value: 1.875402569770813
# ICA with SGD done!0
# Final loss value: 1.8753927946090698
# ICA with SGD done!0
# Final loss value: 1.875382900238037
# ICA with SGD done!0
# Final loss value: 1.8753743171691895
# ICA with SGD done!0
# Final loss value: 1.8753650188446045
# ICA with SGD done!0
# Final loss value: 1.8753559589385986
# ICA with SGD done!0
# Final loss value: 1.875347375869751
# ICA with SGD done!0
# Final loss value: 1.8753390312194824
# ICA with SGD done!0
# Final loss value: 1.8753310441970825
# ICA with SGD done!0
# Final loss value: 1.8753225803375244
# ICA with SGD done!0
# Final loss value: 1.8753148317337036
# ICA with SGD done!0
# Final loss value: 1.8753070831298828
# ICA with SGD done!0
# Final loss value: 1.8752999305725098
# ICA with SGD done!0
# Final loss value: 1.8752925395965576
# ICA with SGD done!0
# Final loss value: 1.8752856254577637
# ICA with SGD done!0
# Final loss value: 1.875278353691101
# ICA with SGD done!0
# Final loss value: 1.8752715587615967
# ICA with SGD done!0
# Final loss value: 1.8752648830413818
# ICA with SGD done!0
# Final loss value: 1.875258445739746
# ICA with SGD done!0
# Final loss value: 1.8752521276474
# ICA with SGD done!0
# Final loss value: 1.8752459287643433
# ICA with SGD done!0
# Final loss value: 1.8752400875091553
# ICA with SGD done!0
# Final loss value: 1.8752341270446777
# ICA with SGD done!0
# Final loss value: 1.8752286434173584
# ICA with SGD done!0
# Final loss value: 1.8752228021621704
# ICA with SGD done!0
# Final loss value: 1.8752174377441406
# ICA with SGD done!0
# Final loss value: 1.8752121925354004
# ICA with SGD done!0
# Final loss value: 1.8752065896987915
# ICA with SGD done!0
# Final loss value: 1.8752018213272095
# ICA with SGD done!0
# Final loss value: 1.8751968145370483
# ICA with SGD done!0
# Final loss value: 1.8751921653747559
# ICA with SGD done!0
# Final loss value: 1.8751870393753052
# ICA with SGD done!0
# Final loss value: 1.8751826286315918
# ICA with SGD done!0
# Final loss value: 1.8751780986785889
# ICA with SGD done!0
# Final loss value: 1.8751739263534546
# ICA with SGD done!0
# Final loss value: 1.8751691579818726
# ICA with SGD done!0
# Final loss value: 1.8751649856567383
# ICA with SGD done!0
# Final loss value: 1.875161051750183
# ICA with SGD done!0
# Final loss value: 1.875157356262207
# ICA with SGD done!0
# Final loss value: 1.8751533031463623
# ICA with SGD done!0
# Final loss value: 1.8751499652862549
# ICA with SGD done!0
# Final loss value: 1.8751459121704102
# ICA with SGD done!0
# Final loss value: 1.875142216682434
# ICA with SGD done!0
# Final loss value: 1.8751386404037476
# ICA with SGD done!0
# Final loss value: 1.8751351833343506
# ICA with SGD done!0
# Final loss value: 1.8751320838928223
# ICA with SGD done!0
# Final loss value: 1.8751288652420044
# ICA with SGD done!0
# Final loss value: 1.875125527381897
# ICA with SGD done!0
# Final loss value: 1.8751224279403687
# ICA with SGD done!0
# Final loss value: 1.8751195669174194
# ICA with SGD done!0
# Final loss value: 1.8751167058944702
# ICA with SGD done!0
# Final loss value: 1.8751133680343628
# ICA with SGD done!0
# Final loss value: 1.8751106262207031
# ICA with SGD done!0
# Final loss value: 1.875108003616333
# ICA with SGD done!0
# Final loss value: 1.8751055002212524
# ICA with SGD done!0
# Final loss value: 1.8751027584075928
# ICA with SGD done!0
# Final loss value: 1.875100016593933
# ICA with SGD done!0
# Final loss value: 1.875097632408142
# ICA with SGD done!0
# Final loss value: 1.875095248222351
# ICA with SGD done!0
# Final loss value: 1.8750929832458496
# ICA with SGD done!0
# Final loss value: 1.8750905990600586
# ICA with SGD done!0
# Final loss value: 1.8750883340835571
# ICA with SGD done!0
# Final loss value: 1.8750860691070557
# ICA with SGD done!0
# Final loss value: 1.8750839233398438
# ICA with SGD done!0
# Final loss value: 1.8750818967819214
# ICA with SGD done!0
# Final loss value: 1.8750799894332886
# ICA with SGD done!0
# Final loss value: 1.8750778436660767
# ICA with SGD done!0
# Final loss value: 1.875076174736023
# ICA with SGD done!0
# Final loss value: 1.8750742673873901
# ICA with SGD done!0
# Final loss value: 1.8750725984573364
# ICA with SGD done!0
# Final loss value: 1.875070333480835
# ICA with SGD done!0
# Final loss value: 1.8750684261322021
# ICA with SGD done!0
# Final loss value: 1.8750667572021484
# ICA with SGD done!0
# Final loss value: 1.8750653266906738
# ICA with SGD done!0
# Final loss value: 1.8750637769699097
# ICA with SGD done!0
# Final loss value: 1.875062108039856
# ICA with SGD done!0
# Final loss value: 1.8750605583190918
# ICA with SGD done!0
# Final loss value: 1.875058889389038
# ICA with SGD done!0
# Final loss value: 1.8750578165054321
# ICA with SGD done!0
# Final loss value: 1.8750563859939575
# ICA with SGD done!0
# Final loss value: 1.8750548362731934
# ICA with SGD done!0
# Final loss value: 1.875053882598877
# ICA with SGD done!0
# Final loss value: 1.8750519752502441
# ICA with SGD done!0
# Final loss value: 1.8750510215759277
# ICA with SGD done!0
# Final loss value: 1.8750494718551636
# ICA with SGD done!0
# Final loss value: 1.8750483989715576
# ICA with SGD done!0
# Final loss value: 1.875047206878662
# ICA with SGD done!0
# Final loss value: 1.8750457763671875
# ICA with SGD done!0
# Final loss value: 1.875044822692871
# ICA with SGD done!0
# Final loss value: 1.8750438690185547
# ICA with SGD done!0
# Final loss value: 1.8750426769256592
# ICA with SGD done!0
# Final loss value: 1.8750416040420532
# ICA with SGD done!0
# Final loss value: 1.8750407695770264
# ICA with SGD done!0
# Final loss value: 1.8750399351119995
# ICA with SGD done!0
# Final loss value: 1.875038743019104
# ICA with SGD done!0
# Final loss value: 1.8750375509262085
# ICA with SGD done!0
# Final loss value: 1.8750364780426025
# ICA with SGD done!0
# Final loss value: 1.8750360012054443
# ICA with SGD done!0
# Final loss value: 1.8750349283218384
# ICA with SGD done!0
# Final loss value: 1.8750338554382324
# ICA with SGD done!0
# Final loss value: 1.8750332593917847
# ICA with SGD done!0
# Final loss value: 1.8750324249267578
# ICA with SGD done!0
# Final loss value: 1.8750317096710205
# ICA with SGD done!0
# Final loss value: 1.8750306367874146
# ICA with SGD done!0
# Final loss value: 1.8750300407409668
# ICA with SGD done!0
# Final loss value: 1.8750290870666504
# ICA with SGD done!0
# Final loss value: 1.8750282526016235
# ICA with SGD done!0
# Final loss value: 1.8750276565551758
# ICA with SGD done!0
# Final loss value: 1.875026822090149
# ICA with SGD done!0
# Final loss value: 1.8750263452529907
# ICA with SGD done!0
# Final loss value: 1.8750258684158325
# ICA with SGD done!0
# Final loss value: 1.8750250339508057
# ICA with SGD done!0
# Final loss value: 1.8750247955322266
# ICA with SGD done!0
# Final loss value: 1.8750237226486206
# ICA with SGD done!0
# Final loss value: 1.8750232458114624
# ICA with SGD done!0
# Final loss value: 1.8750227689743042
# ICA with SGD done!0
# Final loss value: 1.8750221729278564
# ICA with SGD done!0
# Final loss value: 1.8750219345092773
# ICA with SGD done!0
# Final loss value: 1.87502121925354
# ICA with SGD done!0
# Final loss value: 1.8750208616256714
# ICA with SGD done!0
# Final loss value: 1.8750200271606445
# ICA with SGD done!0
# Final loss value: 1.8750197887420654
# ICA with SGD done!0
# Final loss value: 1.8750191926956177
# ICA with SGD done!0
# Final loss value: 1.87501859664917
# ICA with SGD done!0
# Final loss value: 1.8750183582305908
# ICA with SGD done!0
# Final loss value: 1.8750178813934326
# ICA with SGD done!0
# Final loss value: 1.8750172853469849
# ICA with SGD done!0
# Final loss value: 1.8750169277191162
# ICA with SGD done!0
# Final loss value: 1.8750165700912476
# ICA with SGD done!0
# Final loss value: 1.8750160932540894
# ICA with SGD done!0
# Final loss value: 1.8750157356262207
# ICA with SGD done!0
# Final loss value: 1.8750152587890625
# ICA with SGD done!0
# Final loss value: 1.8750152587890625
# ICA with SGD done!0
# Final loss value: 1.8750144243240356
# ICA with SGD done!0
# Final loss value: 1.8750139474868774
# ICA with SGD done!0
# Final loss value: 1.8750139474868774
# ICA with SGD done!0
# Final loss value: 1.8750135898590088
# ICA with SGD done!0
# Final loss value: 1.8750133514404297
# ICA with SGD done!0
# Final loss value: 1.875012993812561
# ICA with SGD done!0
# Final loss value: 1.8750123977661133
# ICA with SGD done!0
# Final loss value: 1.8750122785568237
# ICA with SGD done!0
# Final loss value: 1.8750118017196655
# ICA with SGD done!0
# Final loss value: 1.8750115633010864
# ICA with SGD done!0
# Final loss value: 1.8750113248825073
# ICA with SGD done!0
# Final loss value: 1.8750108480453491
# ICA with SGD done!0
# Final loss value: 1.8750108480453491
# ICA with SGD done!0
# Final loss value: 1.8750109672546387
# ICA with SGD done!0
# Final loss value: 1.8750102519989014
# ICA with SGD done!0
# Final loss value: 1.875010371208191
# ICA with SGD done!0
# Final loss value: 1.8750097751617432
# ICA with SGD done!0
# Final loss value: 1.8750097751617432
# ICA with SGD done!0
# Final loss value: 1.875009536743164
# ICA with SGD done!0
# Final loss value: 1.875009298324585
# ICA with SGD done!0
# Final loss value: 1.8750089406967163
# ICA with SGD done!0
# Final loss value: 1.8750087022781372
# ICA with SGD done!0
# Final loss value: 1.875008463859558
# ICA with SGD done!0
# Final loss value: 1.8750083446502686
# ICA with SGD done!0
# Final loss value: 1.875008225440979
# ICA with SGD done!0
# Final loss value: 1.8750081062316895
# ICA with SGD done!0
# Final loss value: 1.8750073909759521
# ICA with SGD done!0
# Final loss value: 1.8750075101852417
# ICA with SGD done!0
# Final loss value: 1.8750072717666626
# ICA with SGD done!0
# Final loss value: 1.8750072717666626
# ICA with SGD done!0
# Final loss value: 1.875006914138794
# ICA with SGD done!0
# Final loss value: 1.8750067949295044
# ICA with SGD done!0
# Final loss value: 1.8750065565109253
# ICA with SGD done!0
# Final loss value: 1.8750063180923462
# ICA with SGD done!0
# Final loss value: 1.8750064373016357
# ICA with SGD done!0
# Final loss value: 1.8750065565109253
# ICA with SGD done!0
# Final loss value: 1.8750061988830566
# ICA with SGD done!0
# Final loss value: 1.875006079673767
# ICA with SGD done!0
# Final loss value: 1.8750056028366089
# ICA with SGD done!0
# Final loss value: 1.8750056028366089
# ICA with SGD done!0
# Final loss value: 1.8750053644180298
# ICA with SGD done!0
# Final loss value: 1.8750054836273193
# ICA with SGD done!0
# Final loss value: 1.8750052452087402
# ICA with SGD done!0
# Final loss value: 1.8750053644180298
# ICA with SGD done!0
# Final loss value: 1.875004768371582
# ICA with SGD done!0
# Final loss value: 1.8750048875808716
# ICA with SGD done!0
# Final loss value: 1.8750046491622925
# ICA with SGD done!0
# Final loss value: 1.8750046491622925
# ICA with SGD done!0
# Final loss value: 1.8750046491622925
# ICA with SGD done!0
# Final loss value: 1.875004529953003
# ICA with SGD done!0
# Final loss value: 1.8750044107437134
# ICA with SGD done!0
# Final loss value: 1.8750041723251343
# ICA with SGD done!0
# Final loss value: 1.8750039339065552
# ICA with SGD done!0
# Final loss value: 1.8750039339065552
# ICA with SGD done!0
# Final loss value: 1.875003695487976
# ICA with SGD done!0
# Final loss value: 1.8750038146972656
# ICA with SGD done!0
# Final loss value: 1.8750035762786865
# ICA with SGD done!0
# Final loss value: 1.875003457069397
# ICA with SGD done!0
# Final loss value: 1.8750033378601074
# ICA with SGD done!0
# Final loss value: 1.8750030994415283
# ICA with SGD done!0
# Final loss value: 1.875003695487976
# ICA with SGD done!0
# Final loss value: 1.8750035762786865
# ICA with SGD done!0
# Final loss value: 1.8750035762786865
# ICA with SGD done!0
# Final loss value: 1.8750033378601074
# ICA with SGD done!0
# Final loss value: 1.8750035762786865
# ICA with SGD done!0
# Final loss value: 1.8750033378601074
# ICA with SGD done!0
# Final loss value: 1.8750033378601074
# ICA with SGD done!0
# Final loss value: 1.8750033378601074
# ICA with SGD done!0
# Final loss value: 1.8750030994415283
# ICA with SGD done!0
# Final loss value: 1.8750030994415283
# ICA with SGD done!0
# Final loss value: 1.8750028610229492
# ICA with SGD done!0
# Final loss value: 1.875002384185791
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.8750028610229492
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.8750026226043701
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.875002384185791
# ICA with SGD done!0
# Final loss value: 1.8750022649765015
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.8750025033950806
# ICA with SGD done!0
# Final loss value: 1.875002384185791
# ICA with SGD done!0
# Final loss value: 1.875002145767212
# ICA with SGD done!0
# Final loss value: 1.8750020265579224
# ICA with SGD done!0
# Final loss value: 1.8750022649765015
# ICA with SGD done!0
# Final loss value: 1.8750020265579224
# ICA with SGD done!0
# Final loss value: 1.875002145767212
# ICA with SGD done!0
# Final loss value: 1.8750022649765015
# ICA with SGD done!0
# Final loss value: 1.8750019073486328
# ICA with SGD done!0
# Final loss value: 1.8750017881393433
# ICA with SGD done!0
# Final loss value: 1.8750019073486328
# ICA with SGD done!0
# Final loss value: 1.8750016689300537
# ICA with SGD done!0
# Final loss value: 1.8750019073486328
# ICA with SGD done!0
# Final loss value: 1.8750016689300537
# ICA with SGD done!0
# Final loss value: 1.8750015497207642
# ICA with SGD done!0
# Final loss value: 1.8750015497207642
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.8750016689300537
# ICA with SGD done!0
# Final loss value: 1.8750016689300537
# ICA with SGD done!0
# Final loss value: 1.8750017881393433
# ICA with SGD done!0
# Final loss value: 1.8750016689300537
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.875001311302185
# ICA with SGD done!0
# Final loss value: 1.875001311302185
# ICA with SGD done!0
# Final loss value: 1.8750011920928955
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.875001311302185
# ICA with SGD done!0
# Final loss value: 1.875001311302185
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750015497207642
# ICA with SGD done!0
# Final loss value: 1.875001311302185
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.8750015497207642
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750011920928955
# ICA with SGD done!0
# Final loss value: 1.8750014305114746
# ICA with SGD done!0
# Final loss value: 1.875001311302185
# ICA with SGD done!0
# Final loss value: 1.8750011920928955
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750011920928955
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750011920928955
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750011920928955
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.875001072883606
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750008344650269
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750009536743164
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.8749998807907104
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750001192092896
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750005960464478
# ICA with SGD done!0
# Final loss value: 1.8750007152557373
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750004768371582
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.8750003576278687
# ICA with SGD done!0
# Final loss value: 1.875000238418579
